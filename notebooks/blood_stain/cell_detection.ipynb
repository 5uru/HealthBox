# %%
from ultralytics import YOLO
from PIL import Image
import requests

# %%
import os


os.environ["ROBOFLOW_API_KEY"] = ""

# %%
from roboflow import download_dataset

dataset = download_dataset("https://universe.roboflow.com/clg-vtj9f/blood-cell-detection-bsbvn/dataset/4", "YOLOv11")

# %%
# Load a model
model = YOLO("yolo11n.pt")

# %%
# !ls -R "blood-cell-detection-4"

# %%
# Train the model
model.train(data=f'{dataset.location}/data.yaml', #path to yaml file
            imgsz=640, #image size for training
            batch=8, #number of batch size
            epochs=100, #number of epochs
            device="cpu") #device ‘0’ if gpu else ‘cpu’

# %%
model_path = '/Users/jonathansuru/PycharmProjects/HealthBox/models/cell_detection.onnx'
model = YOLO(model_path, task="detect")

# %%
results = model("/Users/jonathansuru/PycharmProjects/HealthBox/notebooks/blood_stain/blood-cell-detection-4/test/images/BloodImage_00010_jpg.rf.e24fd42722b3113943ab6dee5e34ace8.jpg")
# Out:
# image 1/1 /Users/jonathansuru/PycharmProjects/HealthBox/notebooks/blood_stain/blood-cell-detection-4/test/images/BloodImage_00010_jpg.rf.e24fd42722b3113943ab6dee5e34ace8.jpg: 640x640 20 RBCs, 3 WBCs, 48.1ms
# Speed: 4.1ms preprocess, 48.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'RBC', 1: 'WBC', 2: 'platelets'}
#  obb: None
#  orig_img: array([[[143, 138, 165],
#          [142, 139, 165],
#          [142, 139, 165],
#          ...,
#          [180, 174, 193],
#          [180, 174, 193],
#          [177, 173, 192]],
#
#         [[143, 138, 165],
#          [143, 138, 165],
#          [142, 139, 165],
#          ...,
#          [181, 172, 192],
#          [179, 173, 192],
#          [176, 172, 191]],
#
#         [[143, 138, 165],
#          [143, 138, 165],
#          [142, 139, 165],
#          ...,
#          [180, 171, 191],
#          [178, 172, 191],
#          [175, 171, 190]],
#
#         ...,
#
#         [[179, 201, 207],
#          [176, 198, 204],
#          [172, 191, 198],
#          ...,
#          [171, 181, 191],
#          [167, 175, 188],
#          [162, 170, 183]],
#
# ...
